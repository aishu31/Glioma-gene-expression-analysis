# %%
import pandas as pd


pk=r"/home/shankar/Desktop/pankaj/glioma/dataset/genes/"

bp=pd.read_csv(pk+"upglbp.txt", sep="	")
bp=bp[["Term", "count"]]
bp=bp.iloc[0:10,0:]
bp

mf=pd.read_csv(pk+"upglmf.txt", sep="	")
mf=mf[["Term", "count"]]
mf=mf.iloc[0:10,0:]
mf


cc=pd.read_csv(pk+"upglcc.txt", sep="	")
cc=cc[["Term", "count"]]
cc=cc.iloc[0:10,0:]
cc



gene=pd.concat([bp,cc,mf],axis=0)
gene.head()
# Out:
#                                                 Term     count
# 0  Positive regulation of dendritic cell cytokine...  4.452576
# 1  Cellular response to cytokine stimulus (go:007...  2.688226
# 2  Positive regulation of interleukin-8 productio...  2.653363
# 3      Pre-replicative complex assembly (go:0036388)  2.612233
# 4  Positive regulation of interleukin-6 productio...  2.465515

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(8,10))

width=0.55

barplot=ax.barh(gene["Term"], gene["count"], width,color = 'darkgreen', align='center',alpha = 0.95)
barplot[0].set_color('purple')
barplot[1].set_color('purple')
barplot[2].set_color('purple')
barplot[3].set_color('purple')
barplot[4].set_color('purple')
barplot[5].set_color('purple')
barplot[6].set_color('purple')
barplot[7].set_color('purple')
barplot[8].set_color('purple')
barplot[9].set_color('purple')


barplot[10].set_color('orange')
barplot[11].set_color('orange')
barplot[12].set_color('orange')
barplot[13].set_color('orange')
barplot[14].set_color('orange')
barplot[15].set_color('orange')
barplot[16].set_color('orange')
barplot[17].set_color('orange')
barplot[18].set_color('orange')
barplot[19].set_color('orange')

barplot[20].set_color('crimson')
barplot[21].set_color('crimson')
barplot[22].set_color('crimson')
barplot[23].set_color('crimson')
barplot[24].set_color('crimson')
barplot[25].set_color('crimson')
barplot[26].set_color('crimson')
barplot[27].set_color('crimson')
barplot[28].set_color('crimson')
barplot[29].set_color('crimson')



# plt.ylabel('Gene Count', horizontalalignment='right', y=1.0)

# plt.ylabel('Gene Count', fontsize = 12)

plt.yticks(fontsize = 12,horizontalalignment='right',rotation=0)
plt.xticks(fontsize = 12,rotation=0)

plt.xlabel('-log10P', fontsize = 12)



plt.subplots_adjust(bottom=0.15)
plt.legend((barplot[0], barplot[10], barplot[20]), ('Biological process', "Cellular component",'Molecular function'),prop={"size":12},frameon=False)
plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')
plt.gca().tick_params(width=2)
plt.setp(plt.gca().spines.values(), linewidth=1)
plt.subplots_adjust(hspace=0.5)
plt.show()

fig.savefig(pk+'GO_upontologies.pdf', bbox_inches='tight',format='pdf', dpi=900)

# %%
bp1=pd.read_csv(pk+"downglbp.txt", sep="	")
bp1=bp1[["Term", "count"]]
bp1=bp1.iloc[0:10,0:]
bp1

mf1=pd.read_csv(pk+"downglmf.txt", sep="	")
mf1=mf1[["Term", "count"]]
mf1=mf1.iloc[0:10,0:]
mf1


cc1=pd.read_csv(pk+"downglcc.txt", sep="	")
cc1=cc1[["Term", "count"]]
cc1=cc1.iloc[0:10,0:]
cc1
gene=pd.concat([bp1,cc1,mf1],axis=0)
gene.head()
# Out:
#                                                 Term     count
# 0  Regulation of neurotransmitter receptor activi...  3.740748
# 1        Chemical synaptic transmission (go:0007268)  3.569912
# 2  Regulation of cation channel activity (go:2001...  3.192467
# 3  Regulation of ampa receptor activity (go:2000311)  2.988922
# 4  Modulation of chemical synaptic transmission (...  2.936979

# %%
fig, ax = plt.subplots(figsize=(8,10))

width=0.55

barplot=ax.barh(gene["Term"], gene["count"], width,color = 'darkgreen', align='center',alpha = 0.95)
barplot[0].set_color('purple')
barplot[1].set_color('purple')
barplot[2].set_color('purple')
barplot[3].set_color('purple')
barplot[4].set_color('purple')
barplot[5].set_color('purple')
barplot[6].set_color('purple')
barplot[7].set_color('purple')
barplot[8].set_color('purple')
barplot[9].set_color('purple')


barplot[10].set_color('orange')
barplot[11].set_color('orange')
barplot[12].set_color('orange')
barplot[13].set_color('orange')
barplot[14].set_color('orange')
barplot[15].set_color('orange')
barplot[16].set_color('orange')
barplot[17].set_color('orange')
barplot[18].set_color('orange')
barplot[19].set_color('orange')

barplot[20].set_color('crimson')
barplot[21].set_color('crimson')
barplot[22].set_color('crimson')
barplot[23].set_color('crimson')
barplot[24].set_color('crimson')
barplot[25].set_color('crimson')
barplot[26].set_color('crimson')
barplot[27].set_color('crimson')
barplot[28].set_color('crimson')
barplot[29].set_color('crimson')



# plt.ylabel('Gene Count', horizontalalignment='right', y=1.0)

# plt.ylabel('Gene Count', fontsize = 12)

plt.yticks(fontsize = 12,horizontalalignment='right',rotation=0)
plt.xticks(fontsize = 12,rotation=0)

plt.xlabel('-log10P', fontsize = 12)



plt.subplots_adjust(bottom=0.15)
plt.legend((barplot[0], barplot[10], barplot[20]), ('Biological process', "Cellular component",'Molecular function'),prop={"size":12},frameon=False)
plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')
plt.gca().tick_params(width=2)
plt.setp(plt.gca().spines.values(), linewidth=1)
plt.subplots_adjust(hspace=0.5)
plt.show()

fig.savefig(pk+'GO_downtologies.pdf', bbox_inches='tight',format='pdf', dpi=900)

# %%
###pathways

# %%
dp1=pd.read_csv(pk+"upkegg.txt", sep="	")
dp1=dp1[["Term", "count"]]
dp1=dp1.iloc[0:10,0:]
dp1

dr1=pd.read_csv(pk+"upbio.txt", sep="	")
dr1=dr1[["Term", "count"]]
dr1=dr1.iloc[0:10,0:]
dr1




gene=pd.concat([dp1,dr1],axis=0)
gene.head()
# Out:
#                                 Term     count
# 0         Osteoclast differentiation  2.032646
# 1               Steroid biosynthesis  1.642809
# 2  Pantothenate and CoA biosynthesis  1.621858
# 3                    DNA replication  1.391343
# 4                         Proteasome  1.287263

# %%
dr1.shape
# Out:
# (10, 2)

# %%
fig, ax = plt.subplots(figsize=(8,10))

width=0.55

barplot=ax.barh(gene["Term"], gene["count"], width,color = 'darkgreen', align='center',alpha = 0.95)
barplot[0].set_color('gold')
barplot[1].set_color('gold')
barplot[2].set_color('gold')
barplot[3].set_color('gold')
barplot[4].set_color('gold')
barplot[5].set_color('gold')
barplot[6].set_color('gold')
barplot[7].set_color('gold')
barplot[8].set_color('gold')
barplot[9].set_color('gold')

barplot[10].set_color('green')
barplot[11].set_color('green')
barplot[12].set_color('green')
barplot[13].set_color('green')
barplot[14].set_color('green')
barplot[15].set_color('green')
barplot[16].set_color('green')
barplot[17].set_color('green')
barplot[18].set_color('green')
barplot[19].set_color('green')





plt.yticks(fontsize = 12,horizontalalignment='right',rotation=0)
plt.xticks(fontsize = 12,rotation=0)
plt.xlabel('-log10P', fontsize = 12)
plt.subplots_adjust(bottom=0.15)
plt.legend((barplot[0], barplot[10]), ('Upregulated KEGG pathways', "Upregulated Reactome pathways"),prop={"size":10},bbox_to_anchor=(0., 1.02, 1., .102), loc=3, frameon=True)
plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')
plt.gca().tick_params(width=2)
plt.setp(plt.gca().spines.values(), linewidth=1)
plt.subplots_adjust(hspace=0.5)
plt.show()

fig.savefig(pk+'Pathways.pdf', bbox_inches='tight',format='pdf', dpi=600)

# %%
dp=pd.read_csv(pk+"downkegg.txt", sep="	")
dp=dp[["Term", "count"]]
dp=dp.iloc[0:10,0:]
dp

dr=pd.read_csv(pk+"downbio.txt", sep="	")
dr=dr[["Term", "count"]]
dr=dr.iloc[0:10,0:]
dr

gene=pd.concat([dp,dr],axis=0)
gene.head()
# Out:
#                                     Term     count
# 0  Phosphatidylinositol signaling system  3.083635
# 1                   Dopaminergic synapse  2.698467
# 2                            Endocytosis  1.919028
# 3                      GABAergic synapse  1.906364
# 4                     Morphine addiction  1.887985

# %%
fig, ax = plt.subplots(figsize=(8,10))

width=0.55

barplot=ax.barh(gene["Term"], gene["count"], width,color = 'darkgreen', align='center',alpha = 0.95)
barplot[0].set_color('gold')
barplot[1].set_color('gold')
barplot[2].set_color('gold')
barplot[3].set_color('gold')
barplot[4].set_color('gold')
barplot[5].set_color('gold')
barplot[6].set_color('gold')
barplot[7].set_color('gold')
barplot[8].set_color('gold')
barplot[9].set_color('gold')

barplot[10].set_color('green')
barplot[11].set_color('green')
barplot[12].set_color('green')
barplot[13].set_color('green')
barplot[14].set_color('green')
barplot[15].set_color('green')
barplot[16].set_color('green')
barplot[17].set_color('green')
barplot[18].set_color('green')
barplot[19].set_color('green')





plt.yticks(fontsize = 12,horizontalalignment='right',rotation=0)
plt.xticks(fontsize = 12,rotation=0)
plt.xlabel('-log10P', fontsize = 12)
plt.subplots_adjust(bottom=0.15)
plt.legend((barplot[0], barplot[10]), ('Downregulated KEGG pathways', "Downregulated Reactome pathways"),prop={"size":10},bbox_to_anchor=(0., 1.02, 1., .102), loc=3,frameon=True)
plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')
plt.gca().tick_params(width=2)
plt.setp(plt.gca().spines.values(), linewidth=1)
plt.subplots_adjust(hspace=0.5)
plt.show()

fig.savefig(pk+'Pathwaysdown.pdf', bbox_inches='tight',format='pdf', dpi=600)
